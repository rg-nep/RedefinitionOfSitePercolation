# %% [markdown]
# # configurations

# %% [markdown]
# # Size

# %% [markdown]
# ### for figure size 5x5 inch
#
# font  : DejaVu Sans
#
# x and y axis font size : 16
#
# x and y tick font size : 12
#
# legend font size = 12
#
# not bold

# %% [markdown]
# ### for figure Size 6x4 inch which is the default matplot size
#
# font  : DejaVu Sans
#
# x and y axis font size : 16
#
# x and y tick font size : 12
#
# legend font size = 12
#
# not bold

# %% [markdown]
# ### for figure Size 10x7 inch which is the preffered size
#
# paper size 10 x 7 inch or 5 x 3.5 inch
#
# fig, ax = plt.subplots(figsize=(10,7),  dpi=300, constrained_layout=False)
#
# ax.set_position([0.12, 0.14, 0.82, 0.8])
#
# font  : DejaVu Sans
#
# #### main figure
# x and y axis label font size : 26
#
# x and y tick font size : 20
#
# legend font size = 20
#
# text font size = 20
#
# #### inset
# x and y axis label font size : 18
#
# x and y tick font size : 14
#
# text font size = 16
#
# legend font size = 18
#
# markersize = 8
#
#
# not bold

# %% [markdown]
# https://journals.aps.org/authors/guide-acceptable-color-online-figures-h24

# %% [markdown]
# color sceme. so that when printed in grey scale, it can be understoon

# %% [markdown]
# # check color
#
# black, blue, red, yellow, magenta, green

# %% [markdown]
# all fonts are bold this includes
# 1. x and y ticks
# 2. x and y labels
# 3. inset
# 4. legends

# %% [markdown]
# ### Layout

# %% [markdown]
# https://matplotlib.org/3.1.1/tutorials/intermediate/tight_layout_guide.html
#
# https://matplotlib.org/3.1.1/tutorials/intermediate/constrainedlayout_guide.html
#
# ## WARNING
# Currently Constrained Layout is experimental. The behaviour and API are subject to change, or the whole functionality may be removed without a deprecation period. If you require your plots to be absolutely reproducible, get the Axes positions after running Constrained Layout and use ax.set_position() in your code with constrained_layout=False.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
font = {'family': 'DejaVu Sans',
        'color':  'black',
        'weight': 'bold',
        'size': 16,
        }

font = {'family': 'DejaVu Sans',
        'color':  'black',
        'size': 16,
        }

inside_font = {'family': 'DejaVu Sans',
        'color':  'black',
        'weight': 'bold',
        'size': 6,
        }

def get_font(size):
    return {'family': 'DejaVu Sans',
        'color':  'black',
        'size': size,
        }

# %%
x = np.linspace(-3, 3, 100)
y1 = np.sin(x)
y2 = 1.5*np.sin(2*x)
y3 = 2*np.sin(3*x)

# %%
styles = ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks']
sns.set_style(styles[4])

# %%
fig = plt.figure(figsize=(5, 5), dpi=100)

plt.plot(x, y1, label="y1")
plt.plot(x, y2, label="y2")
plt.plot(x, y3, label="y3")
    
plt.legend(loc=2, fontsize=16)


plt.xlim(-5, 5)
plt.ylim(0.25, 2.5)
# fig.tight_layout(pad=0.7)


plt.xlabel(r'X Label, $\log(L)$', font)
plt.ylabel(r'$\log(C_h)$', font)

# plt.xticks(fontname="DejaVu Sans", fontsize=16)
# plt.yticks(fontname="DejaVu Sans", fontsize=16)

# plt.tick_params(axis='both', which='major', labelsize=16)

fig.text(0.5, 0.5, r"$\alpha/\nu={:.4}$".format(0.66666), font)
fig.text(0.2, 0.3, "How do you do", font)
# Out:
# Text(0.2, 0.3, 'How do you do')

# %%
plt.rcParams['savefig.facecolor'] = "0.8"
plt.rcParams['figure.figsize'] = 4.5, 4.


def example_plot(ax, fontsize=12, nodec=False):
    ax.plot([1, 2])

    ax.locator_params(nbins=3)
    if not nodec:
        ax.set_xlabel('x-label', fontsize=fontsize)
        ax.set_ylabel('y-label', fontsize=fontsize)
        ax.set_title('Title', fontsize=fontsize)
    else:
        ax.set_xticklabels('')
        ax.set_yticklabels('')

# %%
fig, ax = plt.subplots(figsize=(5,5),dpi=50, constrained_layout=False)
example_plot(ax, fontsize=24)
ax.set_position([0.13, 0.13, 0.8, 0.8])

# %%
fig, ax = plt.subplots(constrained_layout=True)
example_plot(ax, fontsize=24)

# %% [markdown]
# # Color Scheme

# %% [markdown]
# ### Dave Green's cubehelix colour scheme
#
# https://seaborn.pydata.org/tutorial/color_palettes.html#sequential-cubehelix-palettes

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
sns.palplot(sns.cubehelix_palette(n_colors=10,start=1.0, light=0.8, dark=0.1,hue=1, gamma=1,rot=-0.75))

# %%
sns.palplot(sns.cubehelix_palette(n_colors=10,start=1.0, light=0.8, dark=0.1,hue=1, gamma=1,rot=0.75))

# %%
sns.palplot(sns.color_palette("cubehelix", 5))

# %%
sns.palplot(sns.color_palette("BrBG", 7))

# %%
sns.palplot(sns.color_palette("RdBu_r", 7))

# %%
sns.palplot(sns.color_palette("coolwarm", 7))

# %%
sns.palplot(sns.diverging_palette(255, 133, l=60, n=7, center="dark"))

# %%
sns.palplot(sns.color_palette("Blues"))

# %%
sns.palplot(sns.color_palette("BuGn_r"))

# %%
sns.palplot(sns.color_palette("cubehelix", 8))

# %%
sns.palplot(sns.cubehelix_palette(8, start=.5, rot=-.75))

# %%
sns.palplot(sns.cubehelix_palette(8, start=2, rot=0, dark=0, light=.95, reverse=True))

# %%
palette = sns.cubehelix_palette(n_colors=5,start=0, light=0.8, dark=0.1,hue=1, gamma=1,rot=0.75)
sns.palplot(palette)

# %%
palette = sns.cubehelix_palette(n_colors=5,start=0.5, light=0.8, dark=0.1,hue=1, gamma=1,rot=0.75)
sns.palplot(palette)

# %%
palette = sns.cubehelix_palette(n_colors=5,start=1.0, light=0.8, dark=0.1,hue=1, gamma=1,rot=0.75)
sns.palplot(palette)

# %%
palette = sns.cubehelix_palette(n_colors=5,start=1.5, light=0.8, dark=0.1,hue=1, gamma=1,rot=0.75)
sns.palplot(palette)

# %%
palette = sns.cubehelix_palette(n_colors=5,start=2.0, light=0.8, dark=0.1,hue=1, gamma=1,rot=-0.5)
sns.palplot(palette)

# %%
palette = sns.cubehelix_palette(n_colors=5,start=2.5, light=0.8, dark=0.1,hue=1, gamma=1,rot=0.75)
sns.palplot(palette)

# %%
n = 6
for i in np.linspace(0,3,10):
    print(i)
    palette = sns.cubehelix_palette(n_colors=n, start=i, light=0.8, dark=0.07, hue=1, gamma=1,rot=3/n)
    sns.palplot(palette)
# Out:
# 0.0
# 0.3333333333333333
# 0.6666666666666666
# 1.0
# 1.3333333333333333
# 1.6666666666666665
# 2.0
# 2.333333333333333
# 2.6666666666666665
# 3.0

# %%
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt

# %%
fmri = sns.load_dataset("fmri")

# %%
fmri['event'].unique()
# Out:
# array(['stim', 'cue'], dtype=object)

# %%
ax = sns.lineplot(x="timepoint", y="signal", data=fmri)

# %%
ax = sns.lineplot(x="timepoint", y="signal", style="event", data=fmri)

# %%
ax = sns.lineplot(x="timepoint", y="signal", hue="event", style="event", data=fmri)

# %%
ax = sns.lineplot(x="timepoint", y="signal", hue="event", style="event", markers=True, dashes=False, data=fmri)

# %%
ax = sns.lineplot(x="timepoint", y="signal", hue="event", style="event", markers=True, dashes=False, data=fmri)

# %% [markdown]
# # Using Custome Color

# %%
# digonto vai nature paper
colors = ['black', 'magenta', 'green', 'deepskyblue', 'orange']

colors = ['black', 'magenta', 'green', 'dodgerblue', 'gold']

# ok 1
colors = ['black', 'purple', 'magenta', 'green', 'dodgerblue', 'orange', 'gold']


# customizing
colors = ['black', 'purple', 'magenta', 'green', 'dodgerblue', 'darkgoldenrod', 'orange', 'gold']

# %%
spikes = np.linspace(0, 1, 2000)
size=spikes.shape[0]//len(colors)
# fig, ax = plt.subplots(figsize=(5,5), dpi=300)

for a in range(len(colors)):
    plt.eventplot(spikes[a*size:(a+1)*size], orientation='horizontal', linelengths=0.9, color = colors[a], label=colors[a])
    pass
# plt.show()
plt.legend()
plt.ylim([0.5,2])
# plt.savefig("../color.png")
print("convert to grayscaled using : GIMP -> Image -> Mode -> Grayscale")
# Out:
# convert to grayscaled using : GIMP -> Image -> Mode -> Grayscale

# %% [markdown]
# ## Functions to convert colors

# %%
# def rgb2gray(rgb):
#     """
#     rgb is a numpy 3D array
#     """
#     r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
#     gray = 0.2989 * r + 0.5870 * g + 0.1140 * b

#     return gray


def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])


def rgb_to_gray(rgb):
    r, g, b = rgb
    gray = 0.2989 * r + 0.5870 * g + 0.1140 * b
    return gray

# %%
spikes = 100*np.random.random(100)
ck = [(0.3,0.3,0.5)]
plt.eventplot(spikes, orientation='horizontal', linelengths=0.9, color = ck)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-93eec36daca0> in <module>
# ----> 1 spikes = 100*np.random.random(100)
#       2 ck = [(0.3,0.3,0.5)]
#       3 plt.eventplot(spikes, orientation='horizontal', linelengths=0.9, color = ck)
#       4
#       5 plt.show()
#
# NameError: name 'np' is not defined

# %% [markdown]
# ## Gnuplot color map

# %%
number = 7
cmap = plt.get_cmap('gnuplot')
colors = [cmap(i) for i in np.linspace(0, 1, number)]
colors
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9a69a8e2e26f> in <module>
#       1 number = 10
# ----> 2 cmap = plt.get_cmap('gnuplot')
#       3 colors = [cmap(i) for i in np.linspace(0, 1, number)]
#       4 colors
#
# NameError: name 'plt' is not defined

# %%
spikes = np.linspace(0, 1, 2000)
size=spikes.shape[0]//len(colors)
# fig, ax = plt.subplots(figsize=(5,5), dpi=300)

for a in range(len(colors)):
    plt.eventplot(spikes[a*size:(a+1)*size], orientation='horizontal', linelengths=0.9, color = colors[a], label=colors[a])
    pass
# plt.show()
plt.legend()
plt.ylim([0.5,2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4a7163b93ecd> in <module>
# ----> 1 spikes = np.linspace(0, 1, 2000)
#       2 size=spikes.shape[0]//len(colors)
#       3 # fig, ax = plt.subplots(figsize=(5,5), dpi=300)
#       4
#       5 for a in range(len(colors)):
#
# NameError: name 'np' is not defined
